# %% [markdown]
# <a href="https://colab.research.google.com/github/rahamath10/internship-/blob/main/clustering_using_kmean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
X, y_true = make_blobs(
    n_samples=500,
    centers=4,
    cluster_std=0.6,
    random_state=42
)

df = pd.DataFrame(X, columns=["Feature_1", "Feature_2"])
df.head()
# Out:
#    Feature_1  Feature_2
# 0  -8.148764   6.901617
# 1  -8.497759  -6.912687
# 2   5.953761   1.488191
# 3  -2.744463   8.136177
# 4  -6.158899  -7.124955

# %%
plt.scatter(df["Feature_1"], df["Feature_2"])
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Synthetic Dataset (Before Clustering)")
plt.show()

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

df["Cluster"] = clusters

# %%
sil_score = silhouette_score(X_scaled, clusters)
print("Silhouette Score (Accuracy):", sil_score)
# Out:
# Silhouette Score (Accuracy): 0.8801031712426741
